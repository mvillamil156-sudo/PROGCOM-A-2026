# %%
def saludar():
print("Hola")
# Out:
#   File "/tmp/ipykernel_12339/644641294.py", line 2
#     print("Hola")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def saludar():
    print("Hola")  #Un espacio más

# %%
print(nombre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12339/3127010684.py in <cell line: 0>()
# ----> 1 print(nombre)
#
# NameError: name 'nombre' is not defined

# %%
nombre = "Juan"
print(nombre)  #definir variable

# %%
edad = 25
print("Edad: " + edad)  #no se puede concatenar str y int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_12339/519061630.py in <cell line: 0>()
#       1 edad = 25
# ----> 2 print("Edad: " + edad)  # ❌ no puedes concatenar str + int
#
# TypeError: can only concatenate str (not "int") to str

# %%
edad = 25
print("Edad: " + str(edad))
# Out:
# Edad: 25

# %%
lista = [1, 2, 3]
print(lista[5])  #fuera de rango
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_12339/1643024145.py in <cell line: 0>()
#       1 lista = [1, 2, 3]
# ----> 2 print(lista[5])  #fuera de rango
#
# IndexError: list index out of range

# %%
lista = [1, 2, 3]
print(lista[2])
# Out:
# 3

# %%
resultado = 10 / 0  #dividir entre cero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_12339/1655155127.py in <cell line: 0>()
# ----> 1 resultado = 10 / 0  #dividir entre cero
#
# ZeroDivisionError: division by zero

# %%
divisor = 0

if divisor != 0:
    resultado = 10 / divisor
else:
    print("No se puede dividir por cero")
# Out:
# No se puede dividir por cero

# %% [markdown]
# ```java
# public class Main
# {
# 	public static void main(String[] args) {
# 	String texto = null;
#      System.out.println(texto.length()); // NO
# 	}
# }
# ```
#
#
#
# ```java
# String texto = null;
#
# if (texto != null) {
#     System.out.println(texto.length());
# } else {
#     System.out.println("El objeto es null"); // SI
# ```
#
#
# ```java
# int[] numeros = {1, 2, 3};
# System.out.println(numeros[5]); // NO
# ```
#
#
# ```java
# int[] numeros = {1, 2, 3};
# System.out.println(numeros[2]); // SI
# ```
#
#
#
# ```java
# int numero = Integer.parseInt("abc"); // NO
# ```
#
#
#
# ```java
# try {
#     int numero = Integer.parseInt("123"); // SI
# } catch (NumberFormatException e) {
#     System.out.println("Formato inválido");
# }
# ```
#
#
#
# ```java
# int resultado = 10 / 0; // NO
# ```
#
#
# ```java
# int divisor = 0;
#
# if (divisor != 0) {
#     int resultado = 10 / divisor;
# } else {
#     System.out.println("No se puede dividir por cero"); // SI
# }
# ```
#
#
#
# ```java
# Object obj = "Hola";
# Integer num = (Integer) obj; // NO
# ```
#
#
#
# ```java
# Object obj = "Hola";
#
# if (obj instanceof String) {
#     String texto = (String) obj; // SI
# }
# ```
