# %%
import time

def extender_brazos():
    print("extender brazos")
    time.sleep(0.8)

def juntar_manos():
    print("juntar manos")
    time.sleep(0.8)

def elevar_munecas_con_manos_juntas_hacia_arriba():
    print("elevar munecas con manos juntas hacia arriba")
    time.sleep(0.8)

def bajar_munecas_con_manos_juntas_hacia_abajo():
    print("bajar munecas con manos juntas hacia abajo")
    time.sleep(0.8)

def extender_brazos_derecha_e_izquierda():
    print("extender brazos derecha e izquierda")
    time.sleep(0.8)

def subir_en_espiral():
    print("subir en espiral")
    time.sleep(0.8)

def juntas_manos_en_la_parte_de_arriba():
    print("juntas manos en la parte de arriba")
    time.sleep(0.8)

def bajar_manos_en_espiral():
    print("bajar manos en espiral")
    time.sleep(0.8)

def manos_en_la_cabeza():
    print("manos en la cabeza")
    time.sleep(0.8)

def bajar_manos_y_agachar_las_piernas():
    print("bajar manos y agachar las piernas")
    time.sleep(0.8)

def mano_izquierda_al_frente():
    print("mano izquierda al frente")
    time.sleep(0.8)

def remolino_con_mano_izquierda():
    print("remolino con mano izquierda")
    time.sleep(0.8)

def brazo_derecho_doblado():
    print("brazo derecho doblado")
    time.sleep(0.8)

def mano_derecha_en_la_cien():
    print("mano derecha en la cien")
    time.sleep(0.8)

def pierna_derecha_un_paso_al_frente():
    print("pierna derecha un paso al frente")
    time.sleep(0.8)

def brazo_derecho_e_izquierdo_hacia_el_pecho():
    print("brazo derecho e izquierdo hacia el pecho")
    time.sleep(0.8)

def manos_juntas_bajan():
    print("manos juntas bajan")
    time.sleep(0.8)

def estira_el_brazo_derecho_hacia_arriba_y_el_otro_hacia_abajo():
    print("Estirar el brazo derecho hacia arriba y el otro hacia abajo")
    time.sleep(0.8)

def remolino_hacia_arriba():
    print("Remolino hacia arriba")
    time.sleep(0.8)

def brazos_hacia_adelante():
    print("Brazos hacia adelante")
    time.sleep(0.8)

def doblar_manos_hacia_abajo():
    print("Doblar manos hacia abajo")
    time.sleep(0.8)

def mano_izquierda_hacia_la_cabeza():
    print("Mano izquierda hacia la cabeza")
    time.sleep(0.8)

def muneca_mano_izquierda_sube_y_baja():
    print("Muñeca mano izquierda sube y baja")
    time.sleep(0.8)

# %%
def intro_golden():
    extender_brazos()
    juntar_manos()
    elevar_munecas_con_manos_juntas_hacia_arriba()
    bajar_munecas_con_manos_juntas_hacia_abajo()
    extender_brazos_derecha_e_izquierda()
    subir_en_espiral()
    juntas_manos_en_la_parte_de_arriba()
    bajar_manos_en_espiral()
    manos_en_la_cabeza()
    bajar_manos_y_agachar_las_piernas()
    mano_izquierda_al_frente()
    remolino_con_mano_izquierda()
    brazo_derecho_doblado()
    mano_derecha_en_la_cien()
    pierna_derecha_un_paso_al_frente()
    brazo_derecho_e_izquierdo_hacia_el_pecho()
    manos_juntas_bajan()
    estira_el_brazo_derecho_hacia_arriba_y_el_otro_hacia_abajo()
    remolino_hacia_arriba()
    brazos_hacia_adelante()
    doblar_manos_hacia_abajo()
    mano_izquierda_hacia_la_cabeza()
    muneca_mano_izquierda_sube_y_baja()

# %%
intro_golden()
# Out:
# extender brazos
# juntar manos
# elevar munecas con manos juntas hacia arriba
# bajar munecas con manos juntas hacia abajo
# extender brazos derecha e izquierda
# subir en espiral
# juntas manos en la parte de arriba
# bajar manos en espiral
# manos en la cabeza
# bajar manos y agachar las piernas
# mano izquierda al frente
# remolino con mano izquierda
# brazo derecho doblado
# mano derecha en la cien
# pierna derecha un paso al frente
# brazo derecho e izquierdo hacia el pecho
# manos juntas bajan
# Estirar el brazo derecho hacia arriba y el otro hacia abajo
# Remolino hacia arriba
# Brazos hacia adelante
# Doblar manos hacia abajo
# Mano izquierda hacia la cabeza
# Muñeca mano izquierda sube y baja
